# %%
# Add the dependencies. 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create a set of 2000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the citipy module.
from citipy import citipy

# %%
# Create a list for weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Create url for API.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library.
import time
from datetime import datetime

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city.replace(" ","+")
        
    #Log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
#Run an API request for each of the cities.
    try:
        #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

            
        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | dunedin
# Processing Record 4 of Set 1 | arawa
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | fort-de-france
# Processing Record 7 of Set 1 | axim
# Processing Record 8 of Set 1 | thongwa
# Processing Record 9 of Set 1 | san cristobal
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | dingle
# Processing Record 12 of Set 1 | menongue
# Processing Record 13 of Set 1 | maniitsoq
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | adre
# Processing Record 16 of Set 1 | udachnyy
# Processing Record 17 of Set 1 | viperesti
# Processing Record 18 of Set 1 | reyes
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | grenada
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | vlore
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | ambodifototra
# City not found. Skipping
# Processing Record 26 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | vazante
# Processing Record 29 of Set 1 | storslett
# Processing Record 30 of Set 1 | chicomuselo
# Processing Record 31 of Set 1 | peleduy
# Processing Record 32 of Set 1 | katherine
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | lompoc
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | semirom
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | sinnamary
# Processing Record 40 of Set 1 | camana
# Processing Record 41 of Set 1 | baran
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | zhigansk
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | asau
# Processing Record 47 of Set 1 | broome
# Processing Record 48 of Set 1 | saldanha
# Processing Record 49 of Set 1 | tautira
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | mandalgovi
# Processing Record 3 of Set 2 | berdyuzhye
# City not found. Skipping
# Processing Record 4 of Set 2 | gorontalo
# Processing Record 5 of Set 2 | hanyang
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | malakal
# Processing Record 8 of Set 2 | codrington
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | sicamous
# Processing Record 11 of Set 2 | ca mau
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping
# Processing Record 13 of Set 2 | luderitz
# Processing Record 14 of Set 2 | lykhivka
# Processing Record 15 of Set 2 | togur
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | viligili
# City not found. Skipping
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | vila franca do campo
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | shimoda
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | lubango
# Processing Record 26 of Set 2 | nemuro
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | victor harbor
# Processing Record 29 of Set 2 | berlevag
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | kaitangata
# Processing Record 32 of Set 2 | alice springs
# Processing Record 33 of Set 2 | nantucket
# Processing Record 34 of Set 2 | geraldton
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | coquimbo
# Processing Record 38 of Set 2 | cururupu
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | chahal
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | gawler
# Processing Record 43 of Set 2 | uyuni
# Processing Record 44 of Set 2 | danielskuil
# Processing Record 45 of Set 2 | kununurra
# Processing Record 46 of Set 2 | gevrai
# Processing Record 47 of Set 2 | albany
# Processing Record 48 of Set 2 | attawapiskat
# City not found. Skipping
# Processing Record 49 of Set 2 | marystown
# Processing Record 50 of Set 2 | haines junction
# Processing Record 1 of Set 3 | saleaula
# City not found. Skipping
# Processing Record 2 of Set 3 | kaeo
# Processing Record 3 of Set 3 | dongsheng
# Processing Record 4 of Set 3 | umm lajj
# Processing Record 5 of Set 3 | ambilobe
# Processing Record 6 of Set 3 | sao filipe
# Processing Record 7 of Set 3 | katsuura
# Processing Record 8 of Set 3 | auki
# Processing Record 9 of Set 3 | severo-kurilsk
# Processing Record 10 of Set 3 | neuquen
# Processing Record 11 of Set 3 | sakakah
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | tepalcatepec
# Processing Record 16 of Set 3 | ruatoria
# City not found. Skipping
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | tsihombe
# City not found. Skipping
# Processing Record 19 of Set 3 | mweka
# Processing Record 20 of Set 3 | visnes
# Processing Record 21 of Set 3 | te anau
# Processing Record 22 of Set 3 | pisco
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | eskasem
# City not found. Skipping
# Processing Record 25 of Set 3 | port elizabeth
# Processing Record 26 of Set 3 | solnechnyy
# Processing Record 27 of Set 3 | dewas
# Processing Record 28 of Set 3 | kavaratti
# Processing Record 29 of Set 3 | tadine
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | ribeira grande
# Processing Record 32 of Set 3 | olga
# Processing Record 33 of Set 3 | itoman
# Processing Record 34 of Set 3 | palora
# Processing Record 35 of Set 3 | palmer
# Processing Record 36 of Set 3 | karakendzha
# City not found. Skipping
# Processing Record 37 of Set 3 | mangai
# Processing Record 38 of Set 3 | mtambile
# Processing Record 39 of Set 3 | puerto baquerizo moreno
# Processing Record 40 of Set 3 | tiarei
# Processing Record 41 of Set 3 | tevaitoa
# Processing Record 42 of Set 3 | olafsvik
# Processing Record 43 of Set 3 | turtas
# Processing Record 44 of Set 3 | vila do maio
# Processing Record 45 of Set 3 | kudahuvadhoo
# Processing Record 46 of Set 3 | muisne
# Processing Record 47 of Set 3 | kasongo-lunda
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping
# Processing Record 49 of Set 3 | maryville
# Processing Record 50 of Set 3 | villazon
# Processing Record 1 of Set 4 | staicele
# Processing Record 2 of Set 4 | saint-pierre
# Processing Record 3 of Set 4 | amderma
# City not found. Skipping
# Processing Record 4 of Set 4 | takob
# City not found. Skipping
# Processing Record 5 of Set 4 | ust-ishim
# Processing Record 6 of Set 4 | saint-philippe
# Processing Record 7 of Set 4 | husavik
# Processing Record 8 of Set 4 | kalulushi
# Processing Record 9 of Set 4 | fomboni
# Processing Record 10 of Set 4 | ruteng
# Processing Record 11 of Set 4 | aswan
# Processing Record 12 of Set 4 | neepawa
# Processing Record 13 of Set 4 | balabac
# Processing Record 14 of Set 4 | ponta delgada
# Processing Record 15 of Set 4 | yellowknife
# Processing Record 16 of Set 4 | salinas
# Processing Record 17 of Set 4 | fuling
# Processing Record 18 of Set 4 | lere
# Processing Record 19 of Set 4 | marsa matruh
# Processing Record 20 of Set 4 | nalut
# Processing Record 21 of Set 4 | sotnikovskoye
# Processing Record 22 of Set 4 | la ceiba
# Processing Record 23 of Set 4 | new norfolk
# Processing Record 24 of Set 4 | norman wells
# Processing Record 25 of Set 4 | esperance
# Processing Record 26 of Set 4 | sitka
# Processing Record 27 of Set 4 | pouebo
# Processing Record 28 of Set 4 | khandbari
# Processing Record 29 of Set 4 | aloja
# Processing Record 30 of Set 4 | teabo
# Processing Record 31 of Set 4 | plettenberg bay
# Processing Record 32 of Set 4 | sentyabrskiy
# City not found. Skipping
# Processing Record 33 of Set 4 | cayenne
# Processing Record 34 of Set 4 | mpongwe
# Processing Record 35 of Set 4 | talnakh
# Processing Record 36 of Set 4 | labuan
# Processing Record 37 of Set 4 | avarua
# Processing Record 38 of Set 4 | kafue
# Processing Record 39 of Set 4 | baiquan
# Processing Record 40 of Set 4 | severnyy
# Processing Record 41 of Set 4 | tubruq
# City not found. Skipping
# Processing Record 42 of Set 4 | inirida
# Processing Record 43 of Set 4 | durban
# Processing Record 44 of Set 4 | sidirokastron
# City not found. Skipping
# Processing Record 45 of Set 4 | kirkenes
# Processing Record 46 of Set 4 | matamoros
# Processing Record 47 of Set 4 | piskivka
# Processing Record 48 of Set 4 | nanortalik
# Processing Record 49 of Set 4 | ostrovnoy
# Processing Record 50 of Set 4 | karasburg
# Processing Record 1 of Set 5 | alofi
# Processing Record 2 of Set 5 | atambua
# Processing Record 3 of Set 5 | hasaki
# Processing Record 4 of Set 5 | tuktoyaktuk
# Processing Record 5 of Set 5 | barentsburg
# City not found. Skipping
# Processing Record 6 of Set 5 | luangwa
# Processing Record 7 of Set 5 | tiksi
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | nishihara
# Processing Record 10 of Set 5 | leningradskiy
# Processing Record 11 of Set 5 | turukhansk
# Processing Record 12 of Set 5 | san carlos de bariloche
# Processing Record 13 of Set 5 | nordby
# Processing Record 14 of Set 5 | saint-augustin
# Processing Record 15 of Set 5 | hambantota
# Processing Record 16 of Set 5 | beringovskiy
# Processing Record 17 of Set 5 | makakilo city
# Processing Record 18 of Set 5 | tabasalu
# Processing Record 19 of Set 5 | thompson
# Processing Record 20 of Set 5 | angra
# City not found. Skipping
# Processing Record 21 of Set 5 | juchitlan
# Processing Record 22 of Set 5 | anadyr
# Processing Record 23 of Set 5 | camacupa
# Processing Record 24 of Set 5 | paicandu
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | havoysund
# Processing Record 27 of Set 5 | kuche
# City not found. Skipping
# Processing Record 28 of Set 5 | arraial do cabo
# Processing Record 29 of Set 5 | comodoro rivadavia
# Processing Record 30 of Set 5 | ibra
# Processing Record 31 of Set 5 | contai
# Processing Record 32 of Set 5 | rio gallegos
# Processing Record 33 of Set 5 | ilulissat
# Processing Record 34 of Set 5 | lagoa
# Processing Record 35 of Set 5 | mazatlan
# Processing Record 36 of Set 5 | mangaluru
# Processing Record 37 of Set 5 | mutis
# Processing Record 38 of Set 5 | boone
# Processing Record 39 of Set 5 | novotalitsy
# City not found. Skipping
# Processing Record 40 of Set 5 | westport
# Processing Record 41 of Set 5 | rafaela
# Processing Record 42 of Set 5 | tukrah
# Processing Record 43 of Set 5 | verkh-usugli
# Processing Record 44 of Set 5 | kwinana
# Processing Record 45 of Set 5 | mount darwin
# Processing Record 46 of Set 5 | ust-tsilma
# Processing Record 47 of Set 5 | tombouctou
# Processing Record 48 of Set 5 | awjilah
# Processing Record 49 of Set 5 | hobyo
# Processing Record 50 of Set 5 | puerto escondido
# Processing Record 1 of Set 6 | hurghada
# Processing Record 2 of Set 6 | touros
# Processing Record 3 of Set 6 | quatre cocos
# Processing Record 4 of Set 6 | cognac
# Processing Record 5 of Set 6 | biratnagar
# Processing Record 6 of Set 6 | camacari
# Processing Record 7 of Set 6 | garowe
# Processing Record 8 of Set 6 | paamiut
# Processing Record 9 of Set 6 | iqaluit
# Processing Record 10 of Set 6 | springbok
# Processing Record 11 of Set 6 | kahului
# Processing Record 12 of Set 6 | samusu
# City not found. Skipping
# Processing Record 13 of Set 6 | defiance
# Processing Record 14 of Set 6 | sarakhs
# Processing Record 15 of Set 6 | itarema
# Processing Record 16 of Set 6 | jatiroto
# Processing Record 17 of Set 6 | saint george
# Processing Record 18 of Set 6 | poum
# Processing Record 19 of Set 6 | mutsamudu
# City not found. Skipping
# Processing Record 20 of Set 6 | salinopolis
# Processing Record 21 of Set 6 | sovetskiy
# Processing Record 22 of Set 6 | altoona
# Processing Record 23 of Set 6 | manta
# Processing Record 24 of Set 6 | general roca
# Processing Record 25 of Set 6 | young
# Processing Record 26 of Set 6 | dharchula
# Processing Record 27 of Set 6 | nizhneyansk
# City not found. Skipping
# Processing Record 28 of Set 6 | san policarpo
# Processing Record 29 of Set 6 | caravelas
# Processing Record 30 of Set 6 | merauke
# Processing Record 31 of Set 6 | inhambane
# Processing Record 32 of Set 6 | grass valley
# Processing Record 33 of Set 6 | mar del plata
# Processing Record 34 of Set 6 | gwanda
# Processing Record 35 of Set 6 | masterton
# Processing Record 36 of Set 6 | totness
# Processing Record 37 of Set 6 | zhanaozen
# Processing Record 38 of Set 6 | acari
# Processing Record 39 of Set 6 | rize
# Processing Record 40 of Set 6 | cabo san lucas
# Processing Record 41 of Set 6 | bogorodskoye
# Processing Record 42 of Set 6 | seoul
# Processing Record 43 of Set 6 | one hundred mile house
# City not found. Skipping
# Processing Record 44 of Set 6 | naze
# Processing Record 45 of Set 6 | isangel
# Processing Record 46 of Set 6 | villarrica
# Processing Record 47 of Set 6 | vardo
# Processing Record 48 of Set 6 | devyatka
# City not found. Skipping
# Processing Record 49 of Set 6 | calvinia
# Processing Record 50 of Set 6 | georgetown
# Processing Record 1 of Set 7 | sao joao da barra
# Processing Record 2 of Set 7 | faya
# Processing Record 3 of Set 7 | sao geraldo do araguaia
# Processing Record 4 of Set 7 | yamada
# Processing Record 5 of Set 7 | kisangani
# Processing Record 6 of Set 7 | diu
# Processing Record 7 of Set 7 | provideniya
# Processing Record 8 of Set 7 | coahuayana
# Processing Record 9 of Set 7 | vila velha
# Processing Record 10 of Set 7 | yulara
# Processing Record 11 of Set 7 | vila
# Processing Record 12 of Set 7 | goderich
# Processing Record 13 of Set 7 | la ronge
# Processing Record 14 of Set 7 | gorno-chuyskiy
# City not found. Skipping
# Processing Record 15 of Set 7 | bekhtery
# Processing Record 16 of Set 7 | sijunjung
# Processing Record 17 of Set 7 | aktas
# Processing Record 18 of Set 7 | plouzane
# Processing Record 19 of Set 7 | virginia beach
# Processing Record 20 of Set 7 | prainha
# Processing Record 21 of Set 7 | port moresby
# Processing Record 22 of Set 7 | souillac
# Processing Record 23 of Set 7 | majene
# Processing Record 24 of Set 7 | biak
# Processing Record 25 of Set 7 | sergeyevka
# Processing Record 26 of Set 7 | palatka
# Processing Record 27 of Set 7 | adrar
# Processing Record 28 of Set 7 | brandon
# Processing Record 29 of Set 7 | morant bay
# Processing Record 30 of Set 7 | ryotsu
# Processing Record 31 of Set 7 | longlac
# City not found. Skipping
# Processing Record 32 of Set 7 | vaitupu
# City not found. Skipping
# Processing Record 33 of Set 7 | luba
# Processing Record 34 of Set 7 | port lincoln
# Processing Record 35 of Set 7 | alexandria
# Processing Record 36 of Set 7 | pacific grove
# Processing Record 37 of Set 7 | jabiru
# City not found. Skipping
# Processing Record 38 of Set 7 | krasnoselkup
# Processing Record 39 of Set 7 | gradistea
# Processing Record 40 of Set 7 | envira
# Processing Record 41 of Set 7 | ancud
# Processing Record 42 of Set 7 | kuusamo
# Processing Record 43 of Set 7 | huarmey
# Processing Record 44 of Set 7 | khonuu
# City not found. Skipping
# Processing Record 45 of Set 7 | doka
# Processing Record 46 of Set 7 | chardara
# Processing Record 47 of Set 7 | kruisfontein
# Processing Record 48 of Set 7 | altamont
# Processing Record 49 of Set 7 | angoche
# Processing Record 50 of Set 7 | clarksburg
# Processing Record 1 of Set 8 | prince rupert
# Processing Record 2 of Set 8 | sambava
# Processing Record 3 of Set 8 | maceio
# Processing Record 4 of Set 8 | airai
# Processing Record 5 of Set 8 | broken hill
# Processing Record 6 of Set 8 | zarinsk
# Processing Record 7 of Set 8 | raub
# Processing Record 8 of Set 8 | gimli
# Processing Record 9 of Set 8 | lerwick
# Processing Record 10 of Set 8 | yei
# Processing Record 11 of Set 8 | kadykchan
# City not found. Skipping
# Processing Record 12 of Set 8 | okha
# Processing Record 13 of Set 8 | eureka
# Processing Record 14 of Set 8 | mangrol
# Processing Record 15 of Set 8 | ondorhaan
# City not found. Skipping
# Processing Record 16 of Set 8 | markivka
# Processing Record 17 of Set 8 | teya
# Processing Record 18 of Set 8 | anloga
# Processing Record 19 of Set 8 | pouembout
# Processing Record 20 of Set 8 | svetlyy
# Processing Record 21 of Set 8 | merritt
# Processing Record 22 of Set 8 | kholtoson
# Processing Record 23 of Set 8 | palabuhanratu
# City not found. Skipping
# Processing Record 24 of Set 8 | umzimvubu
# City not found. Skipping
# Processing Record 25 of Set 8 | pangnirtung
# Processing Record 26 of Set 8 | zhezkazgan
# Processing Record 27 of Set 8 | rawson
# Processing Record 28 of Set 8 | taft
# Processing Record 29 of Set 8 | siderno
# Processing Record 30 of Set 8 | tuatapere
# Processing Record 31 of Set 8 | halalo
# City not found. Skipping
# Processing Record 32 of Set 8 | kedougou
# Processing Record 33 of Set 8 | bengkulu
# Processing Record 34 of Set 8 | callaway
# Processing Record 35 of Set 8 | mergui
# City not found. Skipping
# Processing Record 36 of Set 8 | lolua
# City not found. Skipping
# Processing Record 37 of Set 8 | heinola
# Processing Record 38 of Set 8 | tumannyy
# City not found. Skipping
# Processing Record 39 of Set 8 | ada
# Processing Record 40 of Set 8 | constitucion
# Processing Record 41 of Set 8 | kalpi
# Processing Record 42 of Set 8 | koutiala
# Processing Record 43 of Set 8 | mahibadhoo
# Processing Record 44 of Set 8 | faanui
# Processing Record 45 of Set 8 | jumla
# Processing Record 46 of Set 8 | willmar
# Processing Record 47 of Set 8 | camopi
# Processing Record 48 of Set 8 | marzuq
# Processing Record 49 of Set 8 | kirakira
# Processing Record 50 of Set 8 | bubaque
# Processing Record 1 of Set 9 | naujoji akmene
# Processing Record 2 of Set 9 | aitape
# Processing Record 3 of Set 9 | ahipara
# Processing Record 4 of Set 9 | grindavik
# Processing Record 5 of Set 9 | porto novo
# Processing Record 6 of Set 9 | mumford
# Processing Record 7 of Set 9 | arcachon
# Processing Record 8 of Set 9 | nueva concepcion
# Processing Record 9 of Set 9 | north platte
# Processing Record 10 of Set 9 | tungor
# Processing Record 11 of Set 9 | chicama
# Processing Record 12 of Set 9 | port hardy
# Processing Record 13 of Set 9 | balkhash
# Processing Record 14 of Set 9 | fortuna
# Processing Record 15 of Set 9 | yialos
# City not found. Skipping
# Processing Record 16 of Set 9 | rungata
# City not found. Skipping
# Processing Record 17 of Set 9 | villanueva de la serena
# Processing Record 18 of Set 9 | lavrentiya
# Processing Record 19 of Set 9 | avera
# Processing Record 20 of Set 9 | tecoanapa
# Processing Record 21 of Set 9 | serenje
# Processing Record 22 of Set 9 | petawawa
# Processing Record 23 of Set 9 | yar-sale
# Processing Record 24 of Set 9 | upernavik
# Processing Record 25 of Set 9 | mount gambier
# Processing Record 26 of Set 9 | srednekolymsk
# Processing Record 27 of Set 9 | hagondange
# Processing Record 28 of Set 9 | mastic beach
# Processing Record 29 of Set 9 | clyde river
# Processing Record 30 of Set 9 | paradwip
# City not found. Skipping
# Processing Record 31 of Set 9 | gatesville
# Processing Record 32 of Set 9 | bilma
# Processing Record 33 of Set 9 | kirando
# Processing Record 34 of Set 9 | camacha
# Processing Record 35 of Set 9 | bajil
# Processing Record 36 of Set 9 | pangai
# Processing Record 37 of Set 9 | bandarbeyla
# Processing Record 38 of Set 9 | ondjiva
# Processing Record 39 of Set 9 | emirdag
# Processing Record 40 of Set 9 | port blair
# Processing Record 41 of Set 9 | rute
# Processing Record 42 of Set 9 | beira
# Processing Record 43 of Set 9 | aybak
# City not found. Skipping
# Processing Record 44 of Set 9 | sai buri
# Processing Record 45 of Set 9 | fairbanks
# Processing Record 46 of Set 9 | kavieng
# Processing Record 47 of Set 9 | abu jubayhah
# City not found. Skipping
# Processing Record 48 of Set 9 | jalu
# Processing Record 49 of Set 9 | aranos
# Processing Record 50 of Set 9 | gondanglegi
# Processing Record 1 of Set 10 | raudeberg
# Processing Record 2 of Set 10 | hamilton
# Processing Record 3 of Set 10 | concepcion de buenos aires
# Processing Record 4 of Set 10 | najran
# Processing Record 5 of Set 10 | lucea
# Processing Record 6 of Set 10 | wajima
# Processing Record 7 of Set 10 | tucuma
# Processing Record 8 of Set 10 | ust-nera
# Processing Record 9 of Set 10 | deniliquin
# Processing Record 10 of Set 10 | baherden
# Processing Record 11 of Set 10 | dabakala
# Processing Record 12 of Set 10 | sorland
# Processing Record 13 of Set 10 | margate
# Processing Record 14 of Set 10 | qeshm
# Processing Record 15 of Set 10 | barcelos
# Processing Record 16 of Set 10 | tual
# Processing Record 17 of Set 10 | cuenca
# Processing Record 18 of Set 10 | azimur
# City not found. Skipping
# Processing Record 19 of Set 10 | henties bay
# Processing Record 20 of Set 10 | mogzon
# Processing Record 21 of Set 10 | grenaa
# Processing Record 22 of Set 10 | aykhal
# Processing Record 23 of Set 10 | la libertad
# Processing Record 24 of Set 10 | visby
# Processing Record 25 of Set 10 | pirganj
# Processing Record 26 of Set 10 | zhoucheng
# Processing Record 27 of Set 10 | namibe
# Processing Record 28 of Set 10 | port-gentil
# Processing Record 29 of Set 10 | bondo
# Processing Record 30 of Set 10 | bonnyville
# Processing Record 31 of Set 10 | salalah
# Processing Record 32 of Set 10 | vinh
# Processing Record 33 of Set 10 | honiara
# Processing Record 34 of Set 10 | marsh harbour
# Processing Record 35 of Set 10 | thiruvananthapuram
# Processing Record 36 of Set 10 | pevek
# Processing Record 37 of Set 10 | luga
# Processing Record 38 of Set 10 | irbit
# Processing Record 39 of Set 10 | cherskiy
# Processing Record 40 of Set 10 | ligayan
# Processing Record 41 of Set 10 | lock haven
# Processing Record 42 of Set 10 | thai binh
# Processing Record 43 of Set 10 | georgiyevskoye
# Processing Record 44 of Set 10 | sosnovo-ozerskoye
# Processing Record 45 of Set 10 | port augusta
# Processing Record 46 of Set 10 | sao goncalo do amarante
# Processing Record 47 of Set 10 | makinsk
# Processing Record 48 of Set 10 | torbay
# Processing Record 49 of Set 10 | gisborne
# Processing Record 50 of Set 10 | padang
# Processing Record 1 of Set 11 | tabiauea
# City not found. Skipping
# Processing Record 2 of Set 11 | coihaique
# Processing Record 3 of Set 11 | aasiaat
# Processing Record 4 of Set 11 | necochea
# Processing Record 5 of Set 11 | port-cartier
# Processing Record 6 of Set 11 | belluno
# Processing Record 7 of Set 11 | pringsewu
# Processing Record 8 of Set 11 | hihifo
# City not found. Skipping
# Processing Record 9 of Set 11 | kichera
# Processing Record 10 of Set 11 | tazmalt
# Processing Record 11 of Set 11 | arnia
# Processing Record 12 of Set 11 | kapit
# Processing Record 13 of Set 11 | vestmannaeyjar
# Processing Record 14 of Set 11 | carnarvon
# Processing Record 15 of Set 11 | hay river
# Processing Record 16 of Set 11 | banswada
# Processing Record 17 of Set 11 | nouadhibou
# Processing Record 18 of Set 11 | puerto cabezas
# Processing Record 19 of Set 11 | mount isa
# Processing Record 20 of Set 11 | nunkini
# Processing Record 21 of Set 11 | daru
# Processing Record 22 of Set 11 | lorengau
# Processing Record 23 of Set 11 | ola
# Processing Record 24 of Set 11 | french harbor
# Processing Record 25 of Set 11 | saint-joseph
# Processing Record 26 of Set 11 | sapulpa
# Processing Record 27 of Set 11 | doctor juan manuel frutos
# Processing Record 28 of Set 11 | khromtau
# Processing Record 29 of Set 11 | bhopal
# Processing Record 30 of Set 11 | atar
# Processing Record 31 of Set 11 | great falls
# Processing Record 32 of Set 11 | amsterdam
# Processing Record 33 of Set 11 | tiznit
# Processing Record 34 of Set 11 | kalmunai
# Processing Record 35 of Set 11 | makasar
# Processing Record 36 of Set 11 | los algarrobos
# Processing Record 37 of Set 11 | sobolevo
# Processing Record 38 of Set 11 | wazzan
# City not found. Skipping
# Processing Record 39 of Set 11 | sorvag
# City not found. Skipping
# Processing Record 40 of Set 11 | chiredzi
# Processing Record 41 of Set 11 | markdale
# Processing Record 42 of Set 11 | grand river south east
# City not found. Skipping
# Processing Record 43 of Set 11 | orillia
# Processing Record 44 of Set 11 | vao
# Processing Record 45 of Set 11 | qasigiannguit
# Processing Record 46 of Set 11 | tungkang
# City not found. Skipping
# Processing Record 47 of Set 11 | cordele
# Processing Record 48 of Set 11 | soligalich
# Processing Record 49 of Set 11 | rocha
# Processing Record 50 of Set 11 | iquique
# Processing Record 1 of Set 12 | gorebridge
# Processing Record 2 of Set 12 | sarkand
# Processing Record 3 of Set 12 | riyadh
# Processing Record 4 of Set 12 | urdzhar
# City not found. Skipping
# Processing Record 5 of Set 12 | vaitape
# Processing Record 6 of Set 12 | klyuchi
# Processing Record 7 of Set 12 | new albany
# Processing Record 8 of Set 12 | falealupo
# City not found. Skipping
# Processing Record 9 of Set 12 | bilibino
# Processing Record 10 of Set 12 | waiouru
# Processing Record 11 of Set 12 | yuzhnouralsk
# Processing Record 12 of Set 12 | veraval
# Processing Record 13 of Set 12 | shirokiy
# Processing Record 14 of Set 12 | ukiah
# Processing Record 15 of Set 12 | tazovskiy
# Processing Record 16 of Set 12 | izhma
# Processing Record 17 of Set 12 | mogadishu
# Processing Record 18 of Set 12 | abu dhabi
# Processing Record 19 of Set 12 | apollonia
# Processing Record 20 of Set 12 | moerai
# Processing Record 21 of Set 12 | buchanan
# Processing Record 22 of Set 12 | fenoarivo
# Processing Record 23 of Set 12 | louisbourg
# City not found. Skipping
# Processing Record 24 of Set 12 | assiniboia
# Processing Record 25 of Set 12 | thinadhoo
# Processing Record 26 of Set 12 | almaznyy
# Processing Record 27 of Set 12 | sur
# Processing Record 28 of Set 12 | nagapattinam
# Processing Record 29 of Set 12 | williamsport
# Processing Record 30 of Set 12 | condega
# Processing Record 31 of Set 12 | poya
# Processing Record 32 of Set 12 | ullapool
# Processing Record 33 of Set 12 | mandera
# Processing Record 34 of Set 12 | qaqortoq
# Processing Record 35 of Set 12 | washington
# Processing Record 36 of Set 12 | novi ligure
# Processing Record 37 of Set 12 | manitowoc
# Processing Record 38 of Set 12 | taoudenni
# Processing Record 39 of Set 12 | mentok
# City not found. Skipping
# Processing Record 40 of Set 12 | changping
# Processing Record 41 of Set 12 | hunza
# City not found. Skipping
# Processing Record 42 of Set 12 | vieksniai
# Processing Record 43 of Set 12 | grand gaube
# Processing Record 44 of Set 12 | viedma
# Processing Record 45 of Set 12 | maldonado
# Processing Record 46 of Set 12 | denpasar
# Processing Record 47 of Set 12 | oktyabrskiy
# Processing Record 48 of Set 12 | meulaboh
# Processing Record 49 of Set 12 | kindu
# Processing Record 50 of Set 12 | inderborskiy
# City not found. Skipping
# Processing Record 1 of Set 13 | hoshcha
# Processing Record 2 of Set 13 | tranas
# Processing Record 3 of Set 13 | dwarka
# Processing Record 4 of Set 13 | sibolga
# Processing Record 5 of Set 13 | tuggurt
# City not found. Skipping
# Processing Record 6 of Set 13 | miandoab
# Processing Record 7 of Set 13 | buseresere
# Processing Record 8 of Set 13 | nabire
# Processing Record 9 of Set 13 | bathsheba
# Processing Record 10 of Set 13 | galgani
# City not found. Skipping
# Processing Record 11 of Set 13 | lata
# Processing Record 12 of Set 13 | hami
# Processing Record 13 of Set 13 | dudinka
# Processing Record 14 of Set 13 | lucapa
# Processing Record 15 of Set 13 | fare
# Processing Record 16 of Set 13 | sao jose da coroa grande
# Processing Record 17 of Set 13 | dunmore east
# Processing Record 18 of Set 13 | beni suef
# Processing Record 19 of Set 13 | guerrero negro
# Processing Record 20 of Set 13 | fountain
# Processing Record 21 of Set 13 | bontang
# Processing Record 22 of Set 13 | mizdah
# Processing Record 23 of Set 13 | issenye
# Processing Record 24 of Set 13 | skagastrond
# City not found. Skipping
# Processing Record 25 of Set 13 | bambanglipuro
# Processing Record 26 of Set 13 | balkanabat
# Processing Record 27 of Set 13 | baruun-urt
# Processing Record 28 of Set 13 | glens falls
# Processing Record 29 of Set 13 | kropotkin
# Processing Record 30 of Set 13 | kon tum
# Processing Record 31 of Set 13 | lengshuitan
# Processing Record 32 of Set 13 | vilya
# Processing Record 33 of Set 13 | hualmay
# Processing Record 34 of Set 13 | taburao
# City not found. Skipping
# Processing Record 35 of Set 13 | novo aripuana
# Processing Record 36 of Set 13 | matata
# Processing Record 37 of Set 13 | nichinan
# Processing Record 38 of Set 13 | lisala
# Processing Record 39 of Set 13 | russell
# Processing Record 40 of Set 13 | portland
# Processing Record 41 of Set 13 | sun city west
# Processing Record 42 of Set 13 | samarai
# Processing Record 43 of Set 13 | aberdeen
# Processing Record 44 of Set 13 | sinkat
# City not found. Skipping
# Processing Record 45 of Set 13 | indramayu
# Processing Record 46 of Set 13 | shimanovsk
# Processing Record 47 of Set 13 | verkhnevilyuysk
# Processing Record 48 of Set 13 | deputatskiy
# Processing Record 49 of Set 13 | ulety
# Processing Record 50 of Set 13 | road town
# Processing Record 1 of Set 14 | jizan
# Processing Record 2 of Set 14 | flinders
# Processing Record 3 of Set 14 | kismayo
# Processing Record 4 of Set 14 | mouzakion
# City not found. Skipping
# Processing Record 5 of Set 14 | ramos arizpe
# Processing Record 6 of Set 14 | ayorou
# Processing Record 7 of Set 14 | tilichiki
# Processing Record 8 of Set 14 | xining
# Processing Record 9 of Set 14 | kenai
# Processing Record 10 of Set 14 | grimsby
# Processing Record 11 of Set 14 | manzil salim
# Processing Record 12 of Set 14 | korla
# Processing Record 13 of Set 14 | nebolchi
# Processing Record 14 of Set 14 | sanawad
# Processing Record 15 of Set 14 | aksu
# Processing Record 16 of Set 14 | chabahar
# Processing Record 17 of Set 14 | pozo colorado
# Processing Record 18 of Set 14 | mansar
# Processing Record 19 of Set 14 | aripuana
# Processing Record 20 of Set 14 | colares
# Processing Record 21 of Set 14 | amahai
# Processing Record 22 of Set 14 | manadhoo
# Processing Record 23 of Set 14 | guajara-mirim
# City not found. Skipping
# Processing Record 24 of Set 14 | port-de-paix
# City not found. Skipping
# Processing Record 25 of Set 14 | beckley
# Processing Record 26 of Set 14 | sandwick
# Processing Record 27 of Set 14 | elban
# Processing Record 28 of Set 14 | shakiso
# Processing Record 29 of Set 14 | mackenzie
# Processing Record 30 of Set 14 | flin flon
# Processing Record 31 of Set 14 | bennington
# Processing Record 32 of Set 14 | swindon
# Processing Record 33 of Set 14 | temaraia
# City not found. Skipping
# Processing Record 34 of Set 14 | strezhevoy
# Processing Record 35 of Set 14 | evensk
# Processing Record 36 of Set 14 | verkhoyansk
# Processing Record 37 of Set 14 | bialystok
# Processing Record 38 of Set 14 | mujiayingzi
# Processing Record 39 of Set 14 | huntsville
# Processing Record 40 of Set 14 | gurgan
# City not found. Skipping
# Processing Record 41 of Set 14 | kvarkeno
# Processing Record 42 of Set 14 | half moon bay
# Processing Record 43 of Set 14 | zeya
# Processing Record 44 of Set 14 | aden
# Processing Record 45 of Set 14 | gobabis
# Processing Record 46 of Set 14 | jinchengjiang
# City not found. Skipping
# Processing Record 47 of Set 14 | sault sainte marie
# Processing Record 48 of Set 14 | sunderland
# Processing Record 49 of Set 14 | luanda
# Processing Record 50 of Set 14 | acarau
# Processing Record 1 of Set 15 | sao felix do xingu
# Processing Record 2 of Set 15 | moron
# Processing Record 3 of Set 15 | muroto
# Processing Record 4 of Set 15 | rio grande
# Processing Record 5 of Set 15 | cabedelo
# Processing Record 6 of Set 15 | terme
# Processing Record 7 of Set 15 | vostok
# Processing Record 8 of Set 15 | mersing
# Processing Record 9 of Set 15 | burnie
# Processing Record 10 of Set 15 | monterey
# Processing Record 11 of Set 15 | pedasi
# Processing Record 12 of Set 15 | egvekinot
# Processing Record 13 of Set 15 | birin
# Processing Record 14 of Set 15 | nekrasovskiy
# Processing Record 15 of Set 15 | sao mateus do sul
# Processing Record 16 of Set 15 | ergani
# Processing Record 17 of Set 15 | pitimbu
# Processing Record 18 of Set 15 | gravelbourg
# Processing Record 19 of Set 15 | oriximina
# Processing Record 20 of Set 15 | jesenice
# Processing Record 21 of Set 15 | channel-port aux basques
# Processing Record 22 of Set 15 | pochutla
# Processing Record 23 of Set 15 | crotone
# Processing Record 24 of Set 15 | jacareacanga
# Processing Record 25 of Set 15 | rabo de peixe
# Processing Record 26 of Set 15 | novomykolayivka
# Processing Record 27 of Set 15 | ostersund
# Processing Record 28 of Set 15 | sabha
# Processing Record 29 of Set 15 | esmeraldas
# Processing Record 30 of Set 15 | booue
# Processing Record 31 of Set 15 | tura
# Processing Record 32 of Set 15 | ossora
# Processing Record 33 of Set 15 | cap malheureux
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Ushuaia      AR  2022-06-17 01:34:00 -54.8000  -68.3000     31.66
# 1         Dunedin      NZ  2022-06-17 01:43:07 -45.8742  170.5036     46.24
# 2           Arawa      PG  2022-06-17 01:47:29  -6.2132  155.5367     85.32
# 3      Nikolskoye      RU  2022-06-17 01:42:40  59.7035   30.7861     55.87
# 4  Fort-De-France      MQ  2022-06-17 01:47:30  14.6089  -61.0733     80.55
# 5            Axim      GH  2022-06-17 01:47:30   4.8699   -2.2405     75.20
# 6         Thongwa      MM  2022-06-17 01:47:30  16.7619   96.5278     82.56
# 7   San Cristobal      VE  2022-06-17 01:47:31   7.7669  -72.2250     75.38
# 8          Dikson      RU  2022-06-17 01:45:42  73.5069   80.5464     32.25
# 9          Dingle      PH  2022-06-17 01:47:31  10.9995  122.6711     87.01
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        80          75       13.80          light snow
# 1        67          14        5.48          few clouds
# 2        66          97        5.17     overcast clouds
# 3        75         100        6.31     overcast clouds
# 4        78         100        8.05     overcast clouds
# 5        91          91       10.56          light rain
# 6        73          98        5.23     overcast clouds
# 7        98          36        2.37    scattered clouds
# 8        93         100       10.02     overcast clouds
# 9        68          33        6.96    scattered clouds
